# %%
from sklearn.datasets import make_classification
import numpy as np

# %%
x, y = make_classification(n_samples=500, n_features=2, n_informative=1, n_redundant=0, n_classes=2, n_clusters_per_class=1, hypercube=False, class_sep=10)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x[:, 0], x[:, 1], c=y, cmap='winter')

# %%
def step(z):
    return 1 if z > 0 else 0

def perceptron(x, y):
    x = np.insert(x, 0, 1, axis=1)
    weights = np.ones(x.shape[1])
    lr = 0.1

    for i in range(1000):
        j = np.random.randint(100)
        y_hat = step(np.dot(x[j], weights))
        weights = weights + lr*(y[j] - y_hat) * x[j]

    return weights[0], weights[1:]

# %%
np.dot(np.insert(x[41], 0, 1), [1,1,1])
# Out:
# np.float64(4.617708328150684)

# %%
perceptron(x, y)
# Out:
# (np.float64(0.20000000000000015), array([0.28227944, 1.53319737]))

# %%
intercept_, coef_ = perceptron(x, y)

# %%
m = - (coef_[0] / coef_[1])
b = - (intercept_ / coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m * x_input + b

# %%
plt.plot(x_input, y_input)
plt.scatter(x[:, 0], x[:, 1], c=y, cmap='winter')
